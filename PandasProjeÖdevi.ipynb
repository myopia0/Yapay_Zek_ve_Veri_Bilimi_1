# %% [markdown]
# <a href="https://colab.research.google.com/github/myopia0/Yapay_Zek_ve_Veri_Bilimi_1/blob/main/PandasProje%C3%96devi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import io

uploaded = files.upload()
uploaded1=files.upload()
uploaded2=files.upload()


for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-f6331af5-187f-49b9-9882-3a4583ddae0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6331af5-187f-49b9-9882-3a4583ddae0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
file_name='products (2).csv'

products=pd.read_csv(io.BytesIO(uploaded2[file_name]))
display(products.head())
# Out:
#    product_id product_name    category   price  stock
# 0           1       Ürün 1  Elektronik   88.48     97
# 1           2       Ürün 2        Spor  338.31     81
# 2           3       Ürün 3    Kozmetik  992.33     49
# 3           4       Ürün 4  Elektronik  840.17     65
# 4           5       Ürün 5  Elektronik  369.64     96

# %%
file_name='orders (5).csv'

orders=pd.read_csv(io.BytesIO(uploaded1[file_name]))
display(orders.head())
# Out:
#    order_id  customer_id  product_id  order_date  quantity    price
# 0         1            6           5  2024-05-06         1   369.64
# 1         2           10           2  2024-10-14         1   338.31
# 2         3            5          10  2024-10-02         5  1062.30
# 3         4            1           3  2024-05-14         3   992.33
# 4         5            8           9  2024-10-26         3  1218.44

# %%
file_name='customers (3).csv'

customers=pd.read_csv(io.BytesIO(uploaded[file_name]))
display(customers.head())
# Out:
#    customer_id first_name last_name                     email signup_date  \
# 0            1        Ali    Yılmaz    ali.yılmaz@example.com  2023-11-24
# 1            2       Ayşe      Kaya     ayşe.kaya@example.com  2023-02-27
# 2            3     Mehmet     Demir  mehmet.demir@example.com  2023-01-13
# 3            4      Fatma     Çelik   fatma.çelik@example.com  2023-05-21
# 4            5      Ahmet     Şahin   ahmet.şahin@example.com  2023-05-06
#
#        city
# 0  Istanbul
# 1  Istanbul
# 2  Istanbul
# 3  Istanbul
# 4  Istanbul

# %%
print(products.describe())
print(products.info())
print(orders.describe())
print(orders.info())
print(customers.info())
print(customers.describe())
# Out:
#        product_id        price      stock
# count    10.00000    10.000000   10.00000
# mean      5.50000   709.720000   69.90000
# std       3.02765   452.705915   30.07934
# min       1.00000    59.420000   33.00000
# 25%       3.25000   346.142500   39.25000
# 50%       5.50000   872.305000   73.00000
# 75%       7.75000  1044.807500   96.75000
# max      10.00000  1223.670000  107.00000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    10 non-null     int64
#  1   product_name  10 non-null     object
#  2   category      10 non-null     object
#  3   price         10 non-null     float64
#  4   stock         10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes
# None
#         order_id  customer_id  product_id   quantity        price
# ...
