# %% [markdown]
# <a href="https://colab.research.google.com/github/myopia0/Yapay_Zek_ve_Veri_Bilimi_1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import io

uploaded = files.upload()
uploaded1=files.upload()
uploaded2=files.upload()


for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-874ca387-c408-4c76-9858-9cd4a1c4b014" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-874ca387-c408-4c76-9858-9cd4a1c4b014">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd


file_name =('orders (4).csv')


orders = pd.read_csv(io.BytesIO(uploaded1[file_name]))
print(orders.head())
print(orders.info())
print(orders.describe())
# Out:
#    order_id  customer_id  product_id  order_date  quantity    price
# 0         1            6           5  2024-05-06         1   369.64
# 1         2           10           2  2024-10-14         1   338.31
# 2         3            5          10  2024-10-02         5  1062.30
# 3         4            1           3  2024-05-14         3   992.33
# 4         5            8           9  2024-10-26         3  1218.44
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     30 non-null     int64
#  1   customer_id  30 non-null     int64
#  2   product_id   30 non-null     int64
#  3   order_date   30 non-null     object
#  4   quantity     30 non-null     int64
#  5   price        30 non-null     float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.5+ KB
# None
# ...

# %%
file_name='products (1).csv'

products=pd.read_csv(io.BytesIO(uploaded2[file_name]))
display(products.head())
# Out:
#    product_id product_name    category   price  stock
# 0           1       Ürün 1  Elektronik   88.48     97
# 1           2       Ürün 2        Spor  338.31     81
# 2           3       Ürün 3    Kozmetik  992.33     49
# 3           4       Ürün 4  Elektronik  840.17     65
# 4           5       Ürün 5  Elektronik  369.64     96
